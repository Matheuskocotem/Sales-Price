# %%
import pandas as pd

# %%
dados = pd.read_csv('Data/Sales.csv')

# %%
dados
# Out:
#        TransactionNo       Date ProductNo  \
# 0             581482  12/9/2019     22485
# 1             581475  12/9/2019     22596
# 2             581475  12/9/2019     23235
# 3             581475  12/9/2019     23272
# 4             581475  12/9/2019     23239
# ...              ...        ...       ...
# 536345       C536548  12/1/2018     22168
# 536346       C536548  12/1/2018     21218
# 536347       C536548  12/1/2018     20957
# 536348       C536548  12/1/2018     22580
# 536349       C536548  12/1/2018     22767
#
#                                 ProductName  Price  Quantity  CustomerNo  \
# 0             Set Of 2 Wooden Market Crates  21.47        12     17490.0
# 1       Christmas Star Wish List Chalkboard  10.65        36     13069.0
# 2                  Storage Tin Vintage Leaf  11.53        12     13069.0
# 3         Tree T-Light Holder Willie Winkie  10.65        12     13069.0
# 4         Set Of 4 Knick Knack Tins Poppies  11.94         6     13069.0
# ...

# %%
dados.head(2)
# Out:
#   TransactionNo       Date ProductNo                          ProductName  \
# 0        581482  12/9/2019     22485        Set Of 2 Wooden Market Crates
# 1        581475  12/9/2019     22596  Christmas Star Wish List Chalkboard
#
#    Price  Quantity  CustomerNo         Country
# 0  21.47        12     17490.0  United Kingdom
# 1  10.65        36     13069.0  United Kingdom

# %%
dados.columns
# Out:
# Index(['TransactionNo', 'Date', 'ProductNo', 'ProductName', 'Price',
#        'Quantity', 'CustomerNo', 'Country'],
#       dtype='object')

# %%
dados.index
# Out:
# RangeIndex(start=0, stop=536350, step=1)

# %%
dados['Price']
# Out:
# 0         21.47
# 1         10.65
# 2         11.53
# 3         10.65
# 4         11.94
#           ...
# 536345    18.96
# 536346    14.09
# 536347    11.74
# 536348    16.35
# 536349    20.45
# Name: Price, Length: 536350, dtype: float64

# %%
dados[['ProductName', 'Quantity' ,'Price' ]]
# Out:
#                                 ProductName  Quantity  Price
# 0             Set Of 2 Wooden Market Crates        12  21.47
# 1       Christmas Star Wish List Chalkboard        36  10.65
# 2                  Storage Tin Vintage Leaf        12  11.53
# 3         Tree T-Light Holder Willie Winkie        12  10.65
# 4         Set Of 4 Knick Knack Tins Poppies         6  11.94
# ...                                     ...       ...    ...
# 536345         Organiser Wood Antique White        -2  18.96
# 536346               Red Spotty Biscuit Tin        -3  14.09
# 536347         Porcelain Hanging Bell Small        -1  11.74
# 536348         Advent Calendar Gingham Sack        -4  16.35
# 536349           Triple Photo Frame Cornice        -2  20.45
#
# [536350 rows x 3 columns]

# %%
dados.iloc[1:4]
# Out:
#   TransactionNo       Date ProductNo                          ProductName  \
# 1        581475  12/9/2019     22596  Christmas Star Wish List Chalkboard
# 2        581475  12/9/2019     23235             Storage Tin Vintage Leaf
# 3        581475  12/9/2019     23272    Tree T-Light Holder Willie Winkie
#
#    Price  Quantity  CustomerNo         Country
# 1  10.65        36     13069.0  United Kingdom
# 2  11.53        12     13069.0  United Kingdom
# 3  10.65        12     13069.0  United Kingdom

# %%
dados.iloc[2, 2]
# Out:
# '23235'

# %%
def calculate_total(dados: pd.DataFrame) -> None:

    dados['total'] = dados['Price'] * dados['Quantity']

# %%
dados
# Out:
#        TransactionNo       Date ProductNo  \
# 0             581482  12/9/2019     22485
# 1             581475  12/9/2019     22596
# 2             581475  12/9/2019     23235
# 3             581475  12/9/2019     23272
# 4             581475  12/9/2019     23239
# ...              ...        ...       ...
# 536345       C536548  12/1/2018     22168
# 536346       C536548  12/1/2018     21218
# 536347       C536548  12/1/2018     20957
# 536348       C536548  12/1/2018     22580
# 536349       C536548  12/1/2018     22767
#
#                                 ProductName  Price  Quantity  CustomerNo  \
# 0             Set Of 2 Wooden Market Crates  21.47        12     17490.0
# 1       Christmas Star Wish List Chalkboard  10.65        36     13069.0
# 2                  Storage Tin Vintage Leaf  11.53        12     13069.0
# 3         Tree T-Light Holder Willie Winkie  10.65        12     13069.0
# 4         Set Of 4 Knick Knack Tins Poppies  11.94         6     13069.0
# ...
